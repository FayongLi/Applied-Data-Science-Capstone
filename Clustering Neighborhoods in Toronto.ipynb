# %% [markdown]
# ## Exercise 1: Scraping table from Wikipedia and transforming it to a dataframe

# %% [markdown]
# I first saved the Wikipedia page in HTML format onto my laptop and passed it to BeautifulSoup so that I can extract the table from the webpage.

# %%
from bs4 import BeautifulSoup
import requests

with open('Canada post code.html') as html_file:
	soup = BeautifulSoup(html_file, 'lxml')

output = soup.find('div', class_='mw-parser-output')
table = output.table.tbody.text    # returns a string
#print(table)

# %% [markdown]
# After extracting the table, the first thing that needs to be done is to convert this information into a Python list that contains the following three attributes: postal code, borough, and neighborhood.

# %%
list_ = table.split('\n')
new_list = [i for i in list_ if i != '']
new_list

p =[]
b =[]
n =[]
for i in range(3,len(new_list),3):
    if new_list[i+1] == 'Not assigned':
        continue  
    
    p.append(new_list[i])
    b.append(new_list[i+1])
    if new_list[i+2] != 'Not assigned':
        n.append(new_list[i+2])
    else:
        n.append(new_list[i+1])  # set neighborhood the same name as borough 
#print(p[:10], '\n', b[:10], '\n', n[:10])
  
row = []
for i in range(len(p)):
    row.append([p[i], b[i], n[i]])
#row

# %% [markdown]
# The next step is to convert the list to a pandas dataframe.

# %%
import pandas as pd

columns=['PostalCode', 'Borough', 'Neighborhood']
df = pd.DataFrame(row, columns=columns)
df.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M6A        North York  Lawrence Heights
# 4        M6A        North York    Lawrence Manor

# %% [markdown]
# Obviously, this dataframe contains som duplicate values in the PostalCode column, so let's join the neighborhoods that have the same postal codes and then remove the duplicate rows.

# %%
#Check duplicate rows:
# df[df.duplicated(['PostalCode'])].sort_values(by='PostalCode').head(10)

# %%
# join neighborhoods that have the same postal code 
df_new = df.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(','.join).to_frame().reset_index()
df_new.head()
# Out:
#   PostalCode      Borough                          Neighborhood
# 0        M1B  Scarborough                         Rouge,Malvern
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                Woburn
# 4        M1H  Scarborough                             Cedarbrae

# %%
df_new.shape
# Out:
# (103, 3)

# %% [markdown]
# **This is the solution to exercise 1.**

# %% [markdown]
# ##  Exercise 2: Adding latitude and the longitude information

# %%
df_geo = pd.read_csv('Geospatial_Coordinates.csv')
df_geo.columns = ['PostalCode', 'Latitude', 'Longitude']
#df_geo.set_index('PostalCode', inplace=True)
df_geo.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
df_all = df_new.join(df_geo.set_index('PostalCode'), on='PostalCode')
df_all.head()
# Out:
#   PostalCode      Borough                          Neighborhood   Latitude  \
# 0        M1B  Scarborough                         Rouge,Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3        M1G  Scarborough                                Woburn  43.770992
# 4        M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# **This is the solution to exercise 2.**

# %% [markdown]
# ## Exercise 3: Step 1 -- Visualizing the Neighborhoods

# %% [markdown]
# In the previous dataframe, I assigned the name Queen's Park, the same name as the borough, to one of the rows whose neighborhood information is missing. But this has resulted in two neighborhoods having the same name.I decided to assign a new name to this neighborhood to prevent confusions in future operations.

# %%
df_all.loc[93, 'Neighborhood'] = 'Queen\'s Park Downtown Toronto'

# %%
duplicateRowsDF = df_all[df_all.duplicated(subset='Neighborhood')]
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %% [markdown]
# Now we don't any any duplicate names and can move on to visualizing the neighborhoods on a map.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="TRT_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_all['Latitude'], df_all['Longitude'], df_all['Borough'], df_all['Neighborhood']):
  
    label = borough.upper() + ' : ' + neighborhood
    #'{}, \n {}'.format(borough, neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Step 2 -- Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'DPNNZEDGIAFE3RQAUSL0BV1YTLQFG3VGUFKD45HQAU3M0BJX' # your Foursquare ID
CLIENT_SECRET = 'BU5ZOGKYNLV1ESWZGXMTU2DWC5QCM4DOZN3CTCPOXDCVECLY' # your Foursquare Secret
VERSION = '20191210' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DPNNZEDGIAFE3RQAUSL0BV1YTLQFG3VGUFKD45HQAU3M0BJX
# CLIENT_SECRET:BU5ZOGKYNLV1ESWZGXMTU2DWC5QCM4DOZN3CTCPOXDCVECLY

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### Let's create a function to repeat the same process to all the neighborhoods in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    
    # return a list first, then transform the entire list to a dataframe. 
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    
    return(nearby_venues)

# %%
Toronto_venues = getNearbyVenues(names=df_all['Neighborhood'],
                                   latitudes=df_all['Latitude'],
                                   longitudes=df_all['Longitude']
                                  )

# %%
Toronto_venues.head()
# Out:
#                            Neighborhood  Neighborhood Latitude  \
# 0                         Rouge,Malvern              43.806686
# 1                         Rouge,Malvern              43.806686
# 2  Highland Creek,Rouge Hill,Port Union              43.784535
# 3  Highland Creek,Rouge Hill,Port Union              43.784535
# 4  Highland Creek,Rouge Hill,Port Union              43.784535
#
#    Neighborhood Longitude                      Venue  Venue Latitude  \
# 0              -79.194353                    Wendy's       43.807448
# 1              -79.194353      Interprovincial Group       43.805630
# 2              -79.160497     Chris Effects Painting       43.784343
# 3              -79.160497      Royal Canadian Legion       43.782533
# 4              -79.160497  Affordable Toronto Movers       43.787919
#
#    Venue Longitude              Venue Category
# 0       -79.199056        Fast Food Restaurant
# 1       -79.200378                  Print Shop
# 2       -79.163742  Construction & Landscaping
# 3       -79.163085                         Bar
# 4       -79.162977               Moving Target

# %% [markdown]
# ### Step 3 -- Analyze Each Neighborhood

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")
#print(Toronto_onehot)
# add neighborhood column back to dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 
Toronto_onehot.set_index('Neighborhood', inplace=True)
Toronto_onehot.head()
# Out:
#          Modern European Restaurant  \
# Neighborhood
# Rouge,Malvern                                                  0
# Rouge,Malvern                                                  0
# Highland Creek,Rouge Hill,Port Union                           0
# Highland Creek,Rouge Hill,Port Union                           0
# Highland Creek,Rouge Hill,Port Union                           0
#
#                                       Molecular Gastronomy Restaurant  \
# Neighborhood
# Rouge,Malvern                                                       0
# Rouge,Malvern                                                       0
# Highland Creek,Rouge Hill,Port Union                                0
# Highland Creek,Rouge Hill,Port Union                                0
# Highland Creek,Rouge Hill,Port Union                                0
#
#                                       Monument / Landmark  Motel  \
# Neighborhood
# Rouge,Malvern                                           0      0
# Rouge,Malvern                                           0      0
# Highland Creek,Rouge Hill,Port Union                    0      0
# Highland Creek,Rouge Hill,Port Union                    0      0
# Highland Creek,Rouge Hill,Port Union                    0      0
#
#                                       Movie Theater  Moving Target  Museum  \
# Neighborhood
# Rouge,Malvern                                     0              0       0
# Rouge,Malvern                                     0              0       0
# Highland Creek,Rouge Hill,Port Union              0              0       0
# Highland Creek,Rouge Hill,Port Union              0              0       0
# Highland Creek,Rouge Hill,Port Union              0              1       0
#
#                                       Music Venue  New American Restaurant  \
# Neighborhood
# Rouge,Malvern                                   0                        0
# Rouge,Malvern                                   0                        0
# Highland Creek,Rouge Hill,Port Union            0                        0
# Highland Creek,Rouge Hill,Port Union            0                        0
# Highland Creek,Rouge Hill,Port Union            0                        0
#
#                                       Nightclub  Noodle House  Office  \
# Neighborhood
# Rouge,Malvern                                 0             0       0
# Rouge,Malvern                                 0             0       0
# Highland Creek,Rouge Hill,Port Union          0             0       0
# Highland Creek,Rouge Hill,Port Union          0             0       0
# Highland Creek,Rouge Hill,Port Union          0             0       0
#
#                                       Opera House  Optical Shop  \
# Neighborhood
# Rouge,Malvern                                   0             0
# Rouge,Malvern                                   0             0
# Highland Creek,Rouge Hill,Port Union            0             0
# Highland Creek,Rouge Hill,Port Union            0             0
# Highland Creek,Rouge Hill,Port Union            0             0
#
#                                       Organic Grocery  Other Great Outdoors  \
# Neighborhood
# Rouge,Malvern                                       0                     0
# Rouge,Malvern                                       0                     0
# Highland Creek,Rouge Hill,Port Union                0                     0
# Highland Creek,Rouge Hill,Port Union                0                     0
# Highland Creek,Rouge Hill,Port Union                0                     0
#
#                                       Park  Performing Arts Venue  \
# Neighborhood
# Rouge,Malvern                            0                      0
# Rouge,Malvern                            0                      0
# Highland Creek,Rouge Hill,Port Union     0                      0
# Highland Creek,Rouge Hill,Port Union     0                      0
# Highland Creek,Rouge Hill,Port Union     0                      0
#
#                                       Persian Restaurant  Pet Store  Pharmacy  \
# Neighborhood
# Rouge,Malvern                                          0          0         0
# Rouge,Malvern                                          0          0         0
# Highland Creek,Rouge Hill,Port Union                   0          0         0
# Highland Creek,Rouge Hill,Port Union                   0          0         0
# Highland Creek,Rouge Hill,Port Union                   0          0         0
#
#                                       Piano Bar  Pizza Place  Playground  \
# Neighborhood
# Rouge,Malvern                                 0            0           0
# Rouge,Malvern                                 0            0           0
# Highland Creek,Rouge Hill,Port Union          0            0           0
# Highland Creek,Rouge Hill,Port Union          0            0           0
# Highland Creek,Rouge Hill,Port Union          0            0           0
#
#                                       Plaza  Poke Place  Pool  \
# Neighborhood
# Rouge,Malvern                             0           0     0
# Rouge,Malvern                             0           0     0
# Highland Creek,Rouge Hill,Port Union      0           0     0
# Highland Creek,Rouge Hill,Port Union      0           0     0
# Highland Creek,Rouge Hill,Port Union      0           0     0
#
#                                       Portuguese Restaurant  Poutine Place  \
# Neighborhood
# Rouge,Malvern                                             0              0
# Rouge,Malvern                                             0              0
# Highland Creek,Rouge Hill,Port Union                      0              0
# Highland Creek,Rouge Hill,Port Union                      0              0
# Highland Creek,Rouge Hill,Port Union                      0              0
#
#                                       Print Shop  Pub  Ramen Restaurant  \
# Neighborhood
# Rouge,Malvern                                  0    0                 0
# Rouge,Malvern                                  1    0                 0
# Highland Creek,Rouge Hill,Port Union           0    0                 0
# Highland Creek,Rouge Hill,Port Union           0    0                 0
# Highland Creek,Rouge Hill,Port Union           0    0                 0
#
#                                       Record Shop  Recording Studio  \
# Neighborhood
# Rouge,Malvern                                   0                 0
# Rouge,Malvern                                   0                 0
# Highland Creek,Rouge Hill,Port Union            0                 0
# Highland Creek,Rouge Hill,Port Union            0                 0
# Highland Creek,Rouge Hill,Port Union            0                 0
#
#                                       Rental Car Location  Restaurant  River  \
# Neighborhood
# Rouge,Malvern                                           0           0      0
# Rouge,Malvern                                           0           0      0
# Highland Creek,Rouge Hill,Port Union                    0           0      0
# Highland Creek,Rouge Hill,Port Union                    0           0      0
# Highland Creek,Rouge Hill,Port Union                    0           0      0
#
#                                       Roof Deck  Sake Bar  Salad Place  \
# Neighborhood
# Rouge,Malvern                                 0         0            0
# Rouge,Malvern                                 0         0            0
# Highland Creek,Rouge Hill,Port Union          0         0            0
# Highland Creek,Rouge Hill,Port Union          0         0            0
# Highland Creek,Rouge Hill,Port Union          0         0            0
#
#                                       Salon / Barbershop  Sandwich Place  \
# Neighborhood
# Rouge,Malvern                                          0               0
# Rouge,Malvern                                          0               0
# Highland Creek,Rouge Hill,Port Union                   0               0
# Highland Creek,Rouge Hill,Port Union                   0               0
# Highland Creek,Rouge Hill,Port Union                   0               0
#
#                                       Scenic Lookout  Sculpture Garden  \
# Neighborhood
# Rouge,Malvern                                      0                 0
# Rouge,Malvern                                      0                 0
# Highland Creek,Rouge Hill,Port Union               0                 0
# Highland Creek,Rouge Hill,Port Union               0                 0
# Highland Creek,Rouge Hill,Port Union               0                 0
#
#                                       Seafood Restaurant  Shoe Store  \
# Neighborhood
# Rouge,Malvern                                          0           0
# Rouge,Malvern                                          0           0
# Highland Creek,Rouge Hill,Port Union                   0           0
# Highland Creek,Rouge Hill,Port Union                   0           0
# Highland Creek,Rouge Hill,Port Union                   0           0
#
#                                       Shopping Mall  Skate Park  Skating Rink  \
# Neighborhood
# Rouge,Malvern                                     0           0             0
# Rouge,Malvern                                     0           0             0
# Highland Creek,Rouge Hill,Port Union              0           0             0
# Highland Creek,Rouge Hill,Port Union              0           0             0
# Highland Creek,Rouge Hill,Port Union              0           0             0
#
#                                       Smoke Shop  Smoothie Shop  Soccer Field  \
# Neighborhood
# Rouge,Malvern                                  0              0             0
# Rouge,Malvern                                  0              0             0
# Highland Creek,Rouge Hill,Port Union           0              0             0
# Highland Creek,Rouge Hill,Port Union           0              0             0
# Highland Creek,Rouge Hill,Port Union           0              0             0
#
#                                       Social Club  \
# Neighborhood
# Rouge,Malvern                                   0
# Rouge,Malvern                                   0
# Highland Creek,Rouge Hill,Port Union            0
# Highland Creek,Rouge Hill,Port Union            0
# Highland Creek,Rouge Hill,Port Union            0
#
#                                       Southern / Soul Food Restaurant  Spa  \
# Neighborhood
# Rouge,Malvern                                                       0    0
# Rouge,Malvern                                                       0    0
# Highland Creek,Rouge Hill,Port Union                                0    0
# Highland Creek,Rouge Hill,Port Union                                0    0
# Highland Creek,Rouge Hill,Port Union                                0    0
#
#                                       Speakeasy  Sporting Goods Shop  \
# Neighborhood
# Rouge,Malvern                                 0                    0
# Rouge,Malvern                                 0                    0
# Highland Creek,Rouge Hill,Port Union          0                    0
# Highland Creek,Rouge Hill,Port Union          0                    0
# Highland Creek,Rouge Hill,Port Union          0                    0
#
#                                       Sports Bar  Stadium  Stationery Store  \
# Neighborhood
# Rouge,Malvern                                  0        0                 0
# Rouge,Malvern                                  0        0                 0
# Highland Creek,Rouge Hill,Port Union           0        0                 0
# Highland Creek,Rouge Hill,Port Union           0        0                 0
# Highland Creek,Rouge Hill,Port Union           0        0                 0
#
#                                       Steakhouse  Strip Club  Supermarket  \
# Neighborhood
# Rouge,Malvern                                  0           0            0
# Rouge,Malvern                                  0           0            0
# Highland Creek,Rouge Hill,Port Union           0           0            0
# Highland Creek,Rouge Hill,Port Union           0           0            0
# Highland Creek,Rouge Hill,Port Union           0           0            0
#
#                                       Supplement Shop  Sushi Restaurant  \
# Neighborhood
# Rouge,Malvern                                       0                 0
# Rouge,Malvern                                       0                 0
# Highland Creek,Rouge Hill,Port Union                0                 0
# Highland Creek,Rouge Hill,Port Union                0                 0
# Highland Creek,Rouge Hill,Port Union                0                 0
#
#                                       Swim School  Taco Place  Tailor Shop  \
# Neighborhood
# Rouge,Malvern                                   0           0            0
# Rouge,Malvern                                   0           0            0
# Highland Creek,Rouge Hill,Port Union            0           0            0
# Highland Creek,Rouge Hill,Port Union            0           0            0
# Highland Creek,Rouge Hill,Port Union            0           0            0
#
#                                       Taiwanese Restaurant  Tanning Salon  \
# Neighborhood
# Rouge,Malvern                                            0              0
# Rouge,Malvern                                            0              0
# Highland Creek,Rouge Hill,Port Union                     0              0
# Highland Creek,Rouge Hill,Port Union                     0              0
# Highland Creek,Rouge Hill,Port Union                     0              0
#
#                                       Tea Room  Thai Restaurant  Theater  \
# Neighborhood
# Rouge,Malvern                                0                0        0
# Rouge,Malvern                                0                0        0
# Highland Creek,Rouge Hill,Port Union         0                0        0
# Highland Creek,Rouge Hill,Port Union         0                0        0
# Highland Creek,Rouge Hill,Port Union         0                0        0
#
#                                       Theme Restaurant  \
# Neighborhood
# Rouge,Malvern                                        0
# Rouge,Malvern                                        0
# Highland Creek,Rouge Hill,Port Union                 0
# Highland Creek,Rouge Hill,Port Union                 0
# Highland Creek,Rouge Hill,Port Union                 0
#
#                                       Thrift / Vintage Store  \
# Neighborhood
# Rouge,Malvern                                              0
# Rouge,Malvern                                              0
# Highland Creek,Rouge Hill,Port Union                       0
# Highland Creek,Rouge Hill,Port Union                       0
# Highland Creek,Rouge Hill,Port Union                       0
#
#                                       Toy / Game Store  Trail  Train Station  \
# Neighborhood
# Rouge,Malvern                                        0      0              0
# Rouge,Malvern                                        0      0              0
# Highland Creek,Rouge Hill,Port Union                 0      0              0
# Highland Creek,Rouge Hill,Port Union                 0      0              0
# Highland Creek,Rouge Hill,Port Union                 0      0              0
#
#                                       Vegetarian / Vegan Restaurant  \
# Neighborhood
# Rouge,Malvern                                                     0
# Rouge,Malvern                                                     0
# Highland Creek,Rouge Hill,Port Union                              0
# Highland Creek,Rouge Hill,Port Union                              0
# Highland Creek,Rouge Hill,Port Union                              0
#
#                                       Video Game Store  Video Store  \
# Neighborhood
# Rouge,Malvern                                        0            0
# Rouge,Malvern                                        0            0
# Highland Creek,Rouge Hill,Port Union                 0            0
# Highland Creek,Rouge Hill,Port Union                 0            0
# Highland Creek,Rouge Hill,Port Union                 0            0
#
#                                       Vietnamese Restaurant  Warehouse Store  \
# Neighborhood
# Rouge,Malvern                                             0                0
# Rouge,Malvern                                             0                0
# Highland Creek,Rouge Hill,Port Union                      0                0
# Highland Creek,Rouge Hill,Port Union                      0                0
# Highland Creek,Rouge Hill,Port Union                      0                0
#
#                                       Wine Bar  Wings Joint  Women's Store  \
# Neighborhood
# Rouge,Malvern                                0            0              0
# Rouge,Malvern                                0            0              0
# Highland Creek,Rouge Hill,Port Union         0            0              0
# Highland Creek,Rouge Hill,Port Union         0            0              0
# Highland Creek,Rouge Hill,Port Union         0            0              0
#
#                                       Yoga Studio
# Neighborhood
# Rouge,Malvern                                   0
# Rouge,Malvern                                   0
# Highland Creek,Rouge Hill,Port Union            0
# Highland Creek,Rouge Hill,Port Union            0
# Highland Creek,Rouge Hill,Port Union            0

# %%
#added code 
Toronto_grouped = Toronto_onehot.groupby('Neighborhood').sum().reset_index()

# %% [markdown]
# Let's analyze the first neighborhood and print the top 5 venues in that area.

# %%
#####
temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == 'Adelaide,King,Richmond'].T.reset_index()
temp.columns = ['venue','counts']
temp = temp.iloc[1:]
temp['counts'] = temp['counts'].astype(float)
temp = temp.round({'counts': 2})
temp.sort_values('counts', ascending=False).head().reset_index(drop=True)
# Out:
#              venue  counts
# 0      Coffee Shop     7.0
# 1             Café     5.0
# 2       Steakhouse     4.0
# 3  Thai Restaurant     4.0
# 4       Restaurant     3.0

# %% [markdown]
# I changed the following cell to Markdown to avoid the output, which is too long and not good for displaying the code.

# %% [markdown]
# num_top_venues = 5
#
# for hood in Toronto_grouped['Neighborhood']:
#     print("----"+hood+"----")
#     temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
#     temp.columns = ['venue','counts']
#     temp = temp.iloc[1:]
#     temp['counts'] = temp['counts'].astype(float)
#     temp = temp.round({'counts': 2})
#     print(temp.sort_values('counts', ascending=False).reset_index(drop=True).head(num_top_venues))
#     print('\n')

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  \
# 0                             Adelaide,King,Richmond
# 1                                          Agincourt
# 2  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 3  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 4                              Alderwood,Long Branch
#
#        1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                Coffee Shop                  Café            Steakhouse
# 1  Latin American Restaurant          Skating Rink                Lounge
# 2                       Park   Arts & Crafts Store            Playground
# 3              Grocery Store   Fried Chicken Joint              Pharmacy
# 4                Pizza Place          Skating Rink              Pharmacy
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0       Thai Restaurant            Restaurant                Bakery
# 1        Clothing Store        Breakfast Spot            Donut Shop
# 2               Dog Run      Department Store          Dessert Shop
# 3           Video Store            Beer Store           Pizza Place
# 4                   Pub        Sandwich Place          Dance Studio
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0      Sushi Restaurant                   Bar           Salad Place
# 1    Dim Sum Restaurant                 Diner        Discount Store
# 2    Dim Sum Restaurant                 Diner        Discount Store
# 3  Fast Food Restaurant        Sandwich Place        Discount Store
# 4                   Gym           Coffee Shop            Donut Shop
#
#   10th Most Common Venue
# 0       Asian Restaurant
# 1                Dog Run
# 2       Doner Restaurant
# 3       Department Store
# 4              Drugstore

# %% [markdown]
# ### Step 4 -- Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_#[0:10]
# Out:
# array([1, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 1, 3, 2,
#        0, 2, 2, 2, 2, 1, 0, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4,
#        1, 2, 2, 2, 2, 0, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0,
#        2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0, 4, 2, 2, 1, 1, 0, 0, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2], dtype=int32)

# %%
#Toronto_data
#neighborhoods_venues_sorted.drop(columns='Cluster Labels', inplace=True)
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels                                       Neighborhood  \
# 0               1                             Adelaide,King,Richmond
# 1               2                                          Agincourt
# 2               2  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 3               2  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 4               2                              Alderwood,Long Branch
#
#        1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                Coffee Shop                  Café            Steakhouse
# 1  Latin American Restaurant          Skating Rink                Lounge
# 2                       Park   Arts & Crafts Store            Playground
# 3              Grocery Store   Fried Chicken Joint              Pharmacy
# 4                Pizza Place          Skating Rink              Pharmacy
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0       Thai Restaurant            Restaurant                Bakery
# 1        Clothing Store        Breakfast Spot            Donut Shop
# 2               Dog Run      Department Store          Dessert Shop
# 3           Video Store            Beer Store           Pizza Place
# 4                   Pub        Sandwich Place          Dance Studio
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0      Sushi Restaurant                   Bar           Salad Place
# 1    Dim Sum Restaurant                 Diner        Discount Store
# 2    Dim Sum Restaurant                 Diner        Discount Store
# 3  Fast Food Restaurant        Sandwich Place        Discount Store
# 4                   Gym           Coffee Shop            Donut Shop
#
#   10th Most Common Venue
# 0       Asian Restaurant
# 1                Dog Run
# 2       Doner Restaurant
# 3       Department Store
# 4              Drugstore

# %% [markdown]
# The next step is to merge the **neighborhoods_venues_sorted** dataframe with the **df_all** dataframe. But first we need to check if their dimensions are consistent

# %%
print(df_all.shape)
print(neighborhoods_venues_sorted.shape)
# Out:
# (103, 5)
# (101, 12)

# %% [markdown]
# We can see that the former dataframe has two more rows, i.e. two more neighborhoods, than the latter dataframe. This occurs because no recommended venues were found near these two neighborhoods within the specified distcance, and will cause issues when merging with another dataframe. Therefore, we need to find out what these two neighborhoods are and remove them from our dataframe.

# %%
list1= df_all['Neighborhood'].values.tolist()
list2= neighborhoods_venues_sorted['Neighborhood'].values.tolist()

for i in list1:
    if i not in list2:
        print(i)
# Out:
# Upper Rouge
# Queen's Park Downtown Toronto

# %%
df_all[df_all['Neighborhood'] == 'Upper Rouge']
# Out:
#    PostalCode      Borough Neighborhood   Latitude  Longitude
# 16        M1X  Scarborough  Upper Rouge  43.836125 -79.205636

# %%
df_all[df_all['Neighborhood'] == 'Queen\'s Park Downtown Toronto']
# Out:
#    PostalCode           Borough                   Neighborhood   Latitude  \
# 93        M9A  Downtown Toronto  Queen's Park Downtown Toronto  43.667856
#
#     Longitude
# 93 -79.532242

# %%
# let's drop these two neighborhoods
df_all_dropped = df_all.drop([16,93], axis=0).reset_index()

# %%
Toronto_merged = df_all_dropped

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Toronto_merged.head() # check the last columns!
# Out:
#    index PostalCode      Borough                          Neighborhood  \
# 0      0        M1B  Scarborough                         Rouge,Malvern
# 1      1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      2        M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      3        M1G  Scarborough                                Woburn
# 4      4        M1H  Scarborough                             Cedarbrae
#
#     Latitude  Longitude  Cluster Labels       1st Most Common Venue  \
# 0  43.806686 -79.194353               2        Fast Food Restaurant
# 1  43.784535 -79.160497               2  Construction & Landscaping
# 2  43.763573 -79.188711               2           Electronics Store
# 3  43.770992 -79.216917               2                 Coffee Shop
# 4  43.773136 -79.239476               2         Fried Chicken Joint
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Print Shop           Yoga Studio      Doner Restaurant
# 1         Moving Target                   Bar           Yoga Studio
# 2        Medical Center    Mexican Restaurant                   Spa
# 3              Pharmacy     Korean Restaurant           Yoga Studio
# 4       Thai Restaurant                  Bank    Athletics & Sports
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Dessert Shop    Dim Sum Restaurant                 Diner
# 1      Doner Restaurant    Dim Sum Restaurant                 Diner
# 2        Breakfast Spot           Pizza Place   Rental Car Location
# 3      Doner Restaurant          Dessert Shop    Dim Sum Restaurant
# 4  Caribbean Restaurant           Gas Station      Hakka Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0        Discount Store               Dog Run             Donut Shop
# 1        Discount Store               Dog Run             Donut Shop
# 2          Intersection      Department Store           Dessert Shop
# 3                 Diner        Discount Store                Dog Run
# 4                Bakery   Dumpling Restaurant              Drugstore

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
print('x:', x)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
print('ys:', ys)
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
#print(colors_array)
rainbow = [colors.rgb2hex(i) for i in colors_array]
print(rainbow)

# add markers to the map
markers_colors = []
for lat, lon, nb, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(nb) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# x: [0 1 2 3 4]
# ys: [array([0, 1, 2, 3, 4]), array([ 1,  3,  7, 13, 21]), array([ 2,  7, 20, 41, 70]), array([  3,  13,  41,  87, 151]), array([  4,  21,  70, 151, 264])]
# ['#8000ff', '#00b5eb', '#80ffb4', '#ffb360', '#ff0000']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
neighborhoods_venues_sorted[neighborhoods_venues_sorted['Neighborhood'] == 'Fairview,Henry Farm,Oriole']
# Out:
#     Cluster Labels                Neighborhood 1st Most Common Venue  \
# 43               4  Fairview,Henry Farm,Oriole        Clothing Store
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 43           Coffee Shop  Fast Food Restaurant         Women's Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 43              Tea Room            Food Court                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 43   Japanese Restaurant           Bus Station           Burger Joint

# %% [markdown]
# ### Step 5 -- Examine the clusters

# %% [markdown]
# #### Cluster 1

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, 
                     Toronto_merged.columns[[3] + list(range(7, Toronto_merged.shape[1]))]]
# Out:
#                                   Neighborhood 1st Most Common Venue  \
# 21                            Willowdale South           Coffee Shop
# 37                                     Leaside           Coffee Shop
# 40                 The Danforth West,Riverdale      Greek Restaurant
# 42                             Studio District                  Café
# 46                                  Davisville          Dessert Shop
# 50                  Cabbagetown,St. James Town           Coffee Shop
# 51                        Church and Wellesley      Sushi Restaurant
# 52                                Harbourfront           Coffee Shop
# 55                                 Berczy Park           Coffee Shop
# 61            Bedford Park,Lawrence Manor East      Sushi Restaurant
# 64           The Annex,North Midtown,Yorkville        Sandwich Place
# 65               Harbord,University of Toronto                  Café
# 76                     Little Portugal,Trinity                   Bar
# 77  Brockton,Exhibition Place,Parkdale Village        Breakfast Spot
# 83                           Runnymede,Swansea           Coffee Shop
# 84                                Queen's Park           Coffee Shop
#
#    2nd Most Common Venue   3rd Most Common Venue 4th Most Common Venue  \
# 21      Ramen Restaurant                    Café           Pizza Place
# 37   Sporting Goods Shop  Furniture / Home Store          Burger Joint
# 40           Coffee Shop      Italian Restaurant        Ice Cream Shop
# 42           Coffee Shop                  Bakery    Italian Restaurant
# 46        Sandwich Place             Pizza Place      Sushi Restaurant
# 50            Restaurant             Flower Shop    Italian Restaurant
# 51           Coffee Shop                 Gay Bar   Japanese Restaurant
# 52                  Park                  Bakery                   Pub
# 55            Steakhouse            Cocktail Bar                  Café
# 61           Coffee Shop      Italian Restaurant         Grocery Store
# 64                  Café             Coffee Shop                  Park
# 65             Bookstore                     Bar    Italian Restaurant
# 76            Restaurant             Men's Store      Asian Restaurant
# 77                  Café             Coffee Shop           Yoga Studio
# 83                  Café      Italian Restaurant      Sushi Restaurant
# 84                 Diner        Sushi Restaurant                   Gym
#
#    5th Most Common Venue    6th Most Common Venue    7th Most Common Venue  \
# 21   Japanese Restaurant               Restaurant         Sushi Restaurant
# 37         Grocery Store           Breakfast Spot        Fish & Chips Shop
# 40            Restaurant                Bookstore   Furniture / Home Store
# 42   American Restaurant              Yoga Studio  Comfort Food Restaurant
# 46    Italian Restaurant              Coffee Shop                      Gym
# 50                Bakery                      Pub                     Café
# 51            Restaurant                     Café                    Hotel
# 52            Restaurant           Breakfast Spot                     Café
# 55              Beer Bar              Cheese Shop       Seafood Restaurant
# 61               Butcher                     Café               Restaurant
# 64        Cosmetics Shop             Liquor Store             Burger Joint
# 65   Japanese Restaurant                  Theater           Sandwich Place
# 76           Coffee Shop  New American Restaurant                     Café
# 77                   Gym               Restaurant                Pet Store
# 83         Burrito Place               Restaurant        Electronics Store
# 84                  Park              Yoga Studio                 Beer Bar
#
#        8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 21            Sandwich Place  Fast Food Restaurant             Steakhouse
# 37                Sports Bar            Beer Store          Smoothie Shop
# 40   Fruit & Vegetable Store                   Pub            Pizza Place
# 42        Seafood Restaurant               Brewery         Sandwich Place
# 46                      Café   Fried Chicken Joint     Seafood Restaurant
# 50               Pizza Place         Grocery Store              Pet Store
# 51  Mediterranean Restaurant                   Gym              Gastropub
# 52        Mexican Restaurant               Theater                  Hotel
# 55                    Bakery        Farmers Market                  Hotel
# 61                Hobby Shop     Indian Restaurant   Fast Food Restaurant
# 64         Indian Restaurant                   Pub         History Museum
# 65                Restaurant                Bakery          Poutine Place
# 76               Pizza Place                Bakery  Vietnamese Restaurant
# 77     Performing Arts Venue    Italian Restaurant           Intersection
# 83                 Bookstore                 Diner                    Pub
# 84     Portuguese Restaurant                   Bar          Smoothie Shop

# %% [markdown]
# #### Clusters 2 - 5

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, 
                     Toronto_merged.columns[[3] + list(range(7, Toronto_merged.shape[1]))]]
# Out:
#                                        Neighborhood 1st Most Common Venue  \
# 54                                   St. James Town           Coffee Shop
# 56                               Central Bay Street           Coffee Shop
# 57                           Adelaide,King,Richmond           Coffee Shop
# 58  Harbourfront East,Toronto Islands,Union Station           Coffee Shop
# 59          Design Exchange,Toronto Dominion Centre           Coffee Shop
# 60                    Commerce Court,Victoria Hotel           Coffee Shop
# 68                  Stn A PO Boxes 25 The Esplanade           Coffee Shop
# 69            First Canadian Place,Underground city           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 54                  Café            Restaurant                 Hotel
# 56    Italian Restaurant        Sandwich Place        Ice Cream Shop
# 57                  Café            Steakhouse       Thai Restaurant
# 58              Aquarium                  Café                 Hotel
# 59                  Café                 Hotel            Restaurant
# 60                  Café                 Hotel            Restaurant
# 68                  Café            Restaurant                 Hotel
# 69                  Café            Restaurant            Steakhouse
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 54        Clothing Store        Cosmetics Shop              Beer Bar
# 56          Burger Joint                  Café    Chinese Restaurant
# 57            Restaurant                Bakery      Sushi Restaurant
# 58    Italian Restaurant        Scenic Lookout   Fried Chicken Joint
# 59                   Bar                Bakery    Seafood Restaurant
# 60   American Restaurant         Deli / Bodega    Italian Restaurant
# 68              Beer Bar    Italian Restaurant   Japanese Restaurant
# 69                 Hotel    Seafood Restaurant   Japanese Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 54        Breakfast Spot                 Diner     Italian Restaurant
# 56             Juice Bar   Japanese Restaurant    Fried Chicken Joint
# 57                   Bar           Salad Place       Asian Restaurant
# 58            Restaurant               Brewery                 Bakery
# 59             Gastropub         Deli / Bodega    American Restaurant
# 60                   Gym                Bakery              Gastropub
# 68    Seafood Restaurant          Cocktail Bar                 Bakery
# 69                   Bar      Asian Restaurant          Deli / Bodega

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, 
                     Toronto_merged.columns[[3] + list(range(7, Toronto_merged.shape[1]))]]
# Out:
#             Garden    Health & Beauty Service
# 63                        Trail                       Park
# 67              Airport Service           Airport Terminal
# 70       Furniture / Home Store             Clothing Store
# 71                         Park           Asian Restaurant
# 72                        Trail                      Field
# 73                         Park              Women's Store
# 74                Grocery Store                       Café
# 75                  Supermarket                   Pharmacy
# 78                         Park                     Bakery
# 79            Convenience Store                Coffee Shop
# 80                Grocery Store       Caribbean Restaurant
# 81                          Bar         Mexican Restaurant
# 82                    Gift Shop               Dessert Shop
# 85                        Hotel                Coffee Shop
# 86                   Smoke Shop                Pizza Place
# 87                  Coffee Shop             Sandwich Place
# 88                  Pizza Place               Skating Rink
# 89                        River                       Pool
# 90                         Pool           Business Service
# 91                Grocery Store     Thrift / Vintage Store
# 92          Filipino Restaurant                 Print Shop
# 93            Convenience Store                   Pharmacy
# 94          Empanada Restaurant                Pizza Place
# 95       Furniture / Home Store             Baseball Field
# 96            Convenience Store                       Park
# 97                  Pizza Place  Middle Eastern Restaurant
# 98                         Park                   Bus Line
# 99                Grocery Store        Fried Chicken Joint
# 100         Rental Car Location                        Bar
#
#           3rd Most Common Venue   4th Most Common Venue  \
# 0                   Yoga Studio        Doner Restaurant
# 1                           Bar             Yoga Studio
# 2            Mexican Restaurant                     Spa
# 3             Korean Restaurant             Yoga Studio
# 4                          Bank      Athletics & Sports
# 5                    Donut Shop            Dessert Shop
# 6             Convenience Store             Bus Station
# 7                  Soccer Field           Metro Station
# 8                 Deli / Bodega            Dessert Shop
# 9                  Skating Rink   General Entertainment
# 10       Thrift / Vintage Store               Pet Store
# 11    Middle Eastern Restaurant                  Bakery
# 12                       Lounge          Clothing Store
# 13              Thai Restaurant     Fried Chicken Joint
# 14                   Playground                 Dog Run
# 15                Grocery Store  Thrift / Vintage Store
# 16           Athletics & Sports                 Dog Run
# 18                         Bank     Japanese Restaurant
# 19             Department Store            Dessert Shop
# 20             Doner Restaurant        Department Store
# 22            Convenience Store     Empanada Restaurant
# 23                     Pharmacy             Pizza Place
# 24                  Yoga Studio        Doner Restaurant
# 25         Caribbean Restaurant     Japanese Restaurant
# 26                   Beer Store        Asian Restaurant
# 27           Chinese Restaurant             Supermarket
# 28                  Coffee Shop    Caribbean Restaurant
# 29                   Donut Shop            Dessert Shop
# 30                         Park           Shopping Mall
# 31               Baseball Field        Doner Restaurant
# 32         Gym / Fitness Center            Liquor Store
# 33                  Coffee Shop            Hockey Arena
# 34                         Bank                Bus Line
# 35                   Beer Store            Dance Studio
# 36                          Pub       Health Food Store
# 38                  Yoga Studio             Supermarket
# 39            Convenience Store    Ethiopian Restaurant
# 41            Fish & Chips Shop              Steakhouse
# 43         Gym / Fitness Center                Bus Line
# 44            Food & Drink Shop          Sandwich Place
# 45                  Coffee Shop             Yoga Studio
# 47                   Restaurant             Yoga Studio
# 48                   Bagel Shop              Sports Bar
# 49                   Playground        Department Store
# 62                  Yoga Studio        Doner Restaurant
# 63                Jewelry Store        Sushi Restaurant
# 67               Airport Lounge        Sculpture Garden
# 70            Accessories Store            Carpet Store
# 71          Japanese Restaurant           Metro Station
# 72                 Hockey Arena             Yoga Studio
# 73         Fast Food Restaurant                  Market
# 74                         Park       Convenience Store
# 75                       Bakery                    Bank
# 78   Construction & Landscaping              Donut Shop
# 79               Sandwich Place              Restaurant
# 80                     Bus Line                 Brewery
# 81                         Café         Thai Restaurant
# 82                Movie Theater          Breakfast Spot
# 85                Burrito Place                     Gym
# 86                   Skate Park                 Brewery
# 87                         Café             Flower Shop
# 88                     Pharmacy                     Pub
# 89                Deli / Bodega        Department Store
# 90               Baseball Field        Department Store
# 91            Convenience Store          Discount Store
# 92                  Yoga Studio        Doner Restaurant
# 93                   Beer Store             Pizza Place
# 94                 Home Service             Yoga Studio
# 95                  Yoga Studio           Deli / Bodega
# 96                   Donut Shop            Dessert Shop
# 97                  Coffee Shop          Sandwich Place
# 98                  Pizza Place       Mobile Phone Shop
# 99                     Pharmacy             Video Store
# 100                   Drugstore        Doner Restaurant
#
#            5th Most Common Venue        6th Most Common Venue  \
# 0                   Dessert Shop           Dim Sum Restaurant
# 1               Doner Restaurant           Dim Sum Restaurant
# 2                 Breakfast Spot                  Pizza Place
# 3               Doner Restaurant                 Dessert Shop
# 4           Caribbean Restaurant                  Gas Station
# 5             Dim Sum Restaurant                        Diner
# 6                     Hobby Shop             Department Store
# 7                    Bus Station         Fast Food Restaurant
# 8             Dim Sum Restaurant                        Diner
# 9               Doner Restaurant                 Dessert Shop
# 10         Vietnamese Restaurant       Furniture / Home Store
# 11                   Auto Garage  Eastern European Restaurant
# 12                Breakfast Spot                   Donut Shop
# 13             Convenience Store           Italian Restaurant
# 14              Department Store                 Dessert Shop
# 15                           Gym                     Pharmacy
# 16                          Pool         Fast Food Restaurant
# 18            Dim Sum Restaurant                        Diner
# 19            Dim Sum Restaurant                        Diner
# 20                  Dessert Shop           Dim Sum Restaurant
# 22             Electronics Store  Eastern European Restaurant
# 23                Discount Store                      Dog Run
# 24                  Dessert Shop           Dim Sum Restaurant
# 25                       Dog Run             Department Store
# 26                   Supermarket                 Concert Hall
# 27              Sushi Restaurant    Middle Eastern Restaurant
# 28                Massage Studio                          Bar
# 29            Dim Sum Restaurant                        Diner
# 30                         Hotel                   Comic Shop
# 31            Dim Sum Restaurant                        Diner
# 32                    Donut Shop           Dim Sum Restaurant
# 33                 Deli / Bodega             Department Store
# 34          Gym / Fitness Center                     Pharmacy
# 35                   Curling Ice             Asian Restaurant
# 36           Dumpling Restaurant                    Drugstore
# 38                          Bank                  Coffee Shop
# 39           Empanada Restaurant            Electronics Store
# 41                Ice Cream Shop         Fast Food Restaurant
# 43                   Yoga Studio             Doner Restaurant
# 44                   Pizza Place                         Park
# 45          Gym / Fitness Center      Health & Beauty Service
# 47              Department Store                 Dessert Shop
# 48              Sushi Restaurant        Vietnamese Restaurant
# 49                  Dessert Shop           Dim Sum Restaurant
# 62                  Dessert Shop           Dim Sum Restaurant
# 63                   Yoga Studio                 Dessert Shop
# 67           Rental Car Location                Boat or Ferry
# 70                      Boutique             Fraternity House
# 71                           Pub                  Yoga Studio
# 72                  Dessert Shop           Dim Sum Restaurant
# 73              Doner Restaurant                 Dessert Shop
# 74                    Baby Store                  Candy Store
# 75                          Café    Middle Eastern Restaurant
# 78            Dim Sum Restaurant                        Diner
# 79                       Dog Run             Department Store
# 80              Doner Restaurant           Dim Sum Restaurant
# 81                 Grocery Store    Cajun / Creole Restaurant
# 82   Eastern European Restaurant           Italian Restaurant
# 85           Fried Chicken Joint          American Restaurant
# 86                           Spa               Farmers Market
# 87                    Restaurant          Fried Chicken Joint
# 88                Sandwich Place                 Dance Studio
# 89                  Dessert Shop           Dim Sum Restaurant
# 90            Dim Sum Restaurant                        Diner
# 91                 Burrito Place                 Burger Joint
# 92                  Dessert Shop           Dim Sum Restaurant
# 93                          Café                  Coffee Shop
# 94                       Dog Run             Department Store
# 95                  Dessert Shop           Dim Sum Restaurant
# 96            Dim Sum Restaurant                        Diner
# 97                  Intersection           Chinese Restaurant
# 98                       Dog Run             Department Store
# 99                    Beer Store                  Pizza Place
# 100                 Dessert Shop           Dim Sum Restaurant
#
#            7th Most Common Venue        8th Most Common Venue  \
# 0                          Diner               Discount Store
# 1                          Diner               Discount Store
# 2            Rental Car Location                 Intersection
# 3             Dim Sum Restaurant                        Diner
# 4               Hakka Restaurant                       Bakery
# 5                 Discount Store                      Dog Run
# 6                    Coffee Shop  Eastern European Restaurant
# 7                   Intersection                         Park
# 8                 Discount Store                      Dog Run
# 9             Dim Sum Restaurant                        Diner
# 10              Department Store                 Dessert Shop
# 11           Dumpling Restaurant                    Drugstore
# 12            Dim Sum Restaurant                        Diner
# 13          Fast Food Restaurant           Chinese Restaurant
# 14            Dim Sum Restaurant                        Diner
# 15                   Pizza Place               Sandwich Place
# 16           Dumpling Restaurant                    Drugstore
# 18                Discount Store                      Dog Run
# 19                Discount Store                      Dog Run
# 20                         Diner               Discount Store
# 22           Dumpling Restaurant                    Drugstore
# 23                 Deli / Bodega             Department Store
# 24                         Diner               Discount Store
# 25                  Dessert Shop           Dim Sum Restaurant
# 26                Clothing Store           Chinese Restaurant
# 27                 Deli / Bodega                   Restaurant
# 28                   Yoga Studio               Discount Store
# 29                Discount Store                      Dog Run
# 30            Dim Sum Restaurant              College Stadium
# 31                Discount Store                      Dog Run
# 32                         Diner               Discount Store
# 33                  Dessert Shop           Dim Sum Restaurant
# 34                     Gastropub           Athletics & Sports
# 35                  Skating Rink                  Video Store
# 36                    Donut Shop             Doner Restaurant
# 38                Discount Store                  Gas Station
# 39   Eastern European Restaurant          Dumpling Restaurant
# 41            Italian Restaurant                      Brewery
# 43            Dim Sum Restaurant                        Diner
# 44                           Gym               Breakfast Spot
# 45                         Diner                 Dessert Shop
# 47            Dim Sum Restaurant                        Diner
# 48            Light Rail Station                 Liquor Store
# 49                         Diner               Discount Store
# 62                         Diner               Discount Store
# 63            Dim Sum Restaurant                        Diner
# 67                      Boutique              Harbor / Marina
# 70                   Coffee Shop        Vietnamese Restaurant
# 71                Discount Store                 Dessert Shop
# 72                         Diner               Discount Store
# 73            Dim Sum Restaurant                        Diner
# 74            Athletics & Sports                        Diner
# 75                   Art Gallery                          Bar
# 78                Discount Store                      Dog Run
# 79                  Dessert Shop           Dim Sum Restaurant
# 80                         Diner               Discount Store
# 81                        Bakery                    Speakeasy
# 82                       Dog Run                          Bar
# 85                Sandwich Place     Mediterranean Restaurant
# 86          Fast Food Restaurant                Burrito Place
# 87                   Pizza Place          American Restaurant
# 88                           Gym                  Coffee Shop
# 89                         Diner               Discount Store
# 90                Discount Store                      Dog Run
# 91                Sandwich Place                  Social Club
# 92                         Diner               Discount Store
# 93                  Liquor Store  Eastern European Restaurant
# 94                  Dessert Shop           Dim Sum Restaurant
# 95                         Diner               Discount Store
# 96                Discount Store                      Dog Run
# 97                   Yoga Studio               Discount Store
# 98                  Dessert Shop           Dim Sum Restaurant
# 99          Fast Food Restaurant               Sandwich Place
# 100                        Diner               Discount Store
#
#     9th Most Common Venue   10th Most Common Venue
# 0                 Dog Run               Donut Shop
# 1                 Dog Run               Donut Shop
# 2        Department Store             Dessert Shop
# 3          Discount Store                  Dog Run
# 4     Dumpling Restaurant                Drugstore
# 5        Doner Restaurant                Drugstore
# 6       Electronics Store      Dumpling Restaurant
# 7             Gas Station             Dance Studio
# 8        Doner Restaurant              Yoga Studio
# 9          Discount Store                  Dog Run
# 10     Dim Sum Restaurant                    Diner
# 11             Donut Shop             Dessert Shop
# 12         Discount Store                  Dog Run
# 13               Pharmacy             Noodle House
# 14         Discount Store         Doner Restaurant
# 15        Bubble Tea Shop           Breakfast Spot
# 16             Donut Shop         Doner Restaurant
# 18       Doner Restaurant               Donut Shop
# 19             Donut Shop              College Gym
# 20                Dog Run               Donut Shop
# 22       Department Store               Donut Shop
# 23           Dessert Shop       Dim Sum Restaurant
# 24                Dog Run               Donut Shop
# 25                  Diner           Discount Store
# 26     Dim Sum Restaurant           Discount Store
# 27   Fast Food Restaurant              Pizza Place
# 28     Dim Sum Restaurant                    Diner
# 29       Doner Restaurant                Drugstore
# 30    Empanada Restaurant        Electronics Store
# 31            Yoga Studio             Dessert Shop
# 32                Dog Run         Doner Restaurant
# 33                  Diner           Discount Store
# 34           Intersection             Dessert Shop
# 35               Pharmacy  Comfort Food Restaurant
# 36                Dog Run              Curling Ice
# 38                    Gym             Liquor Store
# 39              Drugstore            Deli / Bodega
# 41           Liquor Store        Food & Drink Shop
# 43         Discount Store                  Dog Run
# 44              Drugstore      Dumpling Restaurant
# 45     Mexican Restaurant           Cosmetics Shop
# 47         Discount Store                  Dog Run
# 48    American Restaurant              Supermarket
# 49                Dog Run         Doner Restaurant
# 62                Dog Run               Donut Shop
# 63         Discount Store                  Dog Run
# 67           Airport Gate                  Airport
# 70     Miscellaneous Shop             Dessert Shop
# 71     Dim Sum Restaurant                    Diner
# 72                Dog Run         Doner Restaurant
# 73         Discount Store                  Dog Run
# 74             Restaurant       Italian Restaurant
# 75             Smoke Shop     Gym / Fitness Center
# 78       Doner Restaurant                Drugstore
# 79                  Diner           Discount Store
# 80                Dog Run               Donut Shop
# 81                  Diner      Fried Chicken Joint
# 82                   Bank               Restaurant
# 85            Yoga Studio       Dim Sum Restaurant
# 86             Restaurant         Recording Studio
# 87   Fast Food Restaurant                 Pharmacy
# 88             Donut Shop                Drugstore
# 89            Yoga Studio             Dance Studio
# 90       Doner Restaurant              Yoga Studio
# 91                 Bakery          Supplement Shop
# 92                Dog Run               Donut Shop
# 93      Electronics Store      Dumpling Restaurant
# 94                  Diner           Discount Store
# 95                Dog Run         Doner Restaurant
# 96       Doner Restaurant              Yoga Studio
# 97           Dessert Shop       Dim Sum Restaurant
# 98                  Diner           Discount Store
# 99         Discount Store         Department Store
# 100               Dog Run               Donut Shop

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, 
                     Toronto_merged.columns[[3] + list(range(7, Toronto_merged.shape[1]))]]
# Out:
#                                Neighborhood 1st Most Common Venue  \
# 66  Chinatown,Grange Park,Kensington Market                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 66                   Bar                Bakery           Coffee Shop
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 66  Vietnamese Restaurant    Mexican Restaurant    Chinese Restaurant
#
#    8th Most Common Venue          9th Most Common Venue 10th Most Common Venue
# 66   Dumpling Restaurant  Vegetarian / Vegan Restaurant          Grocery Store

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, 
                     Toronto_merged.columns[[3] + list(range(7, Toronto_merged.shape[1]))]]
# Out:
#                   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 17  Fairview,Henry Farm,Oriole        Clothing Store           Coffee Shop
# 53     Ryerson,Garden District           Coffee Shop        Clothing Store
#
#    3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 17  Fast Food Restaurant              Women's Store              Tea Room
# 53        Cosmetics Shop  Middle Eastern Restaurant  Fast Food Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 17            Food Court                Bakery   Japanese Restaurant
# 53                  Café            Restaurant       Bubble Tea Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 17           Bus Station           Burger Joint
# 53           Pizza Place              Bookstore
